# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
a = np.random.randint(1000, size=50)
b = np.random.randint(1000, size=50)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
color_array= ["r" if (x+y)%2==0 else 'b' for x,y in zip(a,b)]
ax.scatter(a, b, c = color_array)

# %%
x = np.arange(0, 6)
y1 = 3*x + 0.5
y2 = 5*np.sqrt(x)

# %%
print y1
print y2
# Out:
# [  0.5   3.5   6.5   9.5  12.5  15.5]
# [  0.           5.           7.07106781   8.66025404  10.          11.18033989]

# %%
plt.plot(x, y1, '-.')
plt.plot(x, y2, '-H')
plt.xscale('log')
plt.legend(['3x+0.5','5x^0.5'])
plt.show()

# %%
barheights = [3,5,1]
barlabels = ['grapes', 'oranges', 'hockey pucks']
plt.bar(np.arange(len(barheights)), barheights)
plt.xticks(np.arange(len(barheights)), barlabels, rotation=0)
plt.show()

# %%
plt.figure(figsize=(8,8)) # use this to change the size of the figure
x = np.random.randint(1000, size=50)
y = np.random.randint(1000, size=50)
plt.subplot(2, 2, 1) # (rows, columns, subplot index)
### plotting code here
plt.scatter(x,y)

plt.subplot(2, 2, 2)
### plotting code here
plt.scatter(x,y)

plt.subplot(2, 2, 3)
### plotting code here
plt.scatter(x,y)

plt.subplot(2, 2, 4)
### plotting code here
plt.scatter(x,y)

plt.tight_layout() # ensures that plot titles and axis labels don't overlap
plt.savefig("plot")
plt.show()
